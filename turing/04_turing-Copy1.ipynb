# %% [markdown]
# # 12.4. Simulating a partial differential equation — reaction-diffusion systems and Turing patterns

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a = .1
b = 1.77888506624997
d = 124.961772962027
gamma = 9.245310169791487
#tau = .1
#k = -.005

# %%
size = 100  # size of the 2D grid
dx = 2. / size  # space step

# %%
T = 9.0  # total time
dt = .001  # time step
n = int(T / dt)  # number of iterations

# %%
U = np.random.rand(size, size)
V = np.random.rand(size, size)

# %%
plt.imshow(U, cmap=plt.cm.copper,
              interpolation='bilinear',
              extent=[-1, 1, -1, 1])

# %%
def laplacian(Z):
    Ztop = Z[0:-2, 1:-1]
    Zleft = Z[1:-1, 0:-2]
    Zbottom = Z[2:, 1:-1]
    Zright = Z[1:-1, 2:]
    Zcenter = Z[1:-1, 1:-1]
    return (Ztop + Zleft + Zbottom + Zright -
            4 * Zcenter) / dx**2

# %%
def show_patterns(U, ax=None):
    ax.imshow(U, cmap=plt.cm.copper,
              interpolation='bilinear',
              extent=[-1, 1, -1, 1])
    ax.set_axis_off()

# %%
fig, axes = plt.subplots(3, 3, figsize=(12, 12))
step_plot = n // 9
# We simulate the PDE with the finite difference
# method.
for i in range(n):
    # We compute the Laplacian of u and v.
    deltaU = laplacian(U)
    deltaV = laplacian(V)
    # We take the values of u and v inside the grid.
    Uc = U[1:-1, 1:-1]
    Vc = V[1:-1, 1:-1]
    # We update the variables.
    U[1:-1, 1:-1], V[1:-1, 1:-1] = \
        Uc + dt * (deltaU + gamma*(a - Uc + Uc**2 * Vc)),\
        Vc + dt * (d * deltaV + gamma*(b - Uc**2 * Vc)) 
    # Neumann conditions: derivatives at the edges
    # are null.
    for Z in (U, V):
        Z[0, :] = Z[1, :]
        Z[-1, :] = Z[-2, :]
        Z[:, 0] = Z[:, 1]
        Z[:, -1] = Z[:, -2]

    # We plot the state of the system at
    # 9 different times.
    if i % step_plot == 0 and i < 9 * step_plot:
        ax = axes.flat[i // step_plot]
        show_patterns(U, ax=ax)
        ax.set_title(f'$t={i * dt:.2f}$')
# Out:
# <ipython-input-27-3abe88f7e28e>:14: RuntimeWarning: overflow encountered in square
#   Uc + dt * (deltaU + gamma*(a - Uc + Uc**2 * Vc)),\
# <ipython-input-27-3abe88f7e28e>:14: RuntimeWarning: overflow encountered in multiply
#   Uc + dt * (deltaU + gamma*(a - Uc + Uc**2 * Vc)),\
# <ipython-input-27-3abe88f7e28e>:15: RuntimeWarning: overflow encountered in square
#   Vc + dt * (d * deltaV + gamma*(b - Uc**2 * Vc))
# <ipython-input-27-3abe88f7e28e>:15: RuntimeWarning: overflow encountered in multiply
#   Vc + dt * (d * deltaV + gamma*(b - Uc**2 * Vc))
# <ipython-input-25-4fa2c5342cc4>:7: RuntimeWarning: invalid value encountered in add
#   return (Ztop + Zleft + Zbottom + Zright -
# <ipython-input-25-4fa2c5342cc4>:7: RuntimeWarning: invalid value encountered in subtract
#   return (Ztop + Zleft + Zbottom + Zright -
# <ipython-input-27-3abe88f7e28e>:14: RuntimeWarning: invalid value encountered in add
#   Uc + dt * (deltaU + gamma*(a - Uc + Uc**2 * Vc)),\
# <ipython-input-27-3abe88f7e28e>:15: RuntimeWarning: invalid value encountered in add
#   Vc + dt * (d * deltaV + gamma*(b - Uc**2 * Vc))

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
show_patterns(U, ax=ax)
